# %% [markdown]
# <a href="https://www.kaggle.com/code/hardikdhamija96/indianfoodpreference?scriptVersionId=241013269" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Indian Food Preference: Regional Analysis of Cuisine
# ## 🔷 Objective
# To analyze regional food preferences across India to help food startups customize their menus.
#
#
# <div style="text-align: center;">
#   <img src="https://raw.githubusercontent.com/hardikdhamija96/IndianFoodPreference/refs/heads/main/CoverImage.png" width=1000>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/indian-food-101/indian_food.csv

# %% [markdown]
# ## 🔷 Business Problem
#
# <div style="text-align: center;">
#   <img src="https://raw.githubusercontent.com/hardikdhamija96/IndianFoodPreference/refs/heads/main/ProblemStatement.png" width="400"/>
# </div>

# %%
# Import Libraries

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import dataset
df = pd.read_csv('/kaggle/input/indian-food-101/indian_food.csv')
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %% [markdown]
# ## 🔷 Data Overview

# %%
# columns
df.columns.tolist()
# Out:
# ['name',
#  'ingredients',
#  'diet',
#  'prep_time',
#  'cook_time',
#  'flavor_profile',
#  'course',
#  'state',
#  'region']

# %% [markdown]
# ### 🔹 Columns observations
#
# - `name` -> name of dish
# - `ingredients`- list of ingredients used
# - `diet` - veg/non veg
# - `prep_time` - prepare time in mins
# - `cook_time` - cook time in mins
# - `flavor_profile`- flavour of dish (sweet/salty)
# - `course` - time of food(dinner/lunch/breakfast)
# - `state` - state of india
# - `region` - region in india

# %% [markdown]
# ### 🔹Possible questions we would like to answer !
# - Q1. Famous dishes(names) with respect to region and states
# - Q2. Most widely used ingredients
# - Q3. Top ingredients respect to state and region
# - Q4. Dishes with least ingredients required
# - Q5. Meal course required least number of ingredients
# - Q6. Ratio of diet preference
# - Q7. most veg/non veg wrt states/regions
# - Q8. Avg time required for meal wrt course
# - Q9. Least Time required for course
# - Q10. Which flavour is prefered for a particular meal course
# - Q11. Number of dishes wrt state and region

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 18.1+ KB

# %% [markdown]
# ### 🔹 Observation
# - No null values beside in `region`
# - `ingredients` must be a list
#     - `ingredient_count` can be
# - `prep_time` , `cook_time` are of type int
#     - `total_time` can be derived
# - `diet`,`flavour_profile` ,`course`,`state` and `region` should be category types

# %% [markdown]
# ### 🔹 Values in different features

# %%
# Unique diet
pd.unique(df['diet'])
# Out:
# array(['vegetarian', 'non vegetarian'], dtype=object)

# %%
pd.unique(df['state'])
# Out:
# array(['West Bengal', 'Rajasthan', 'Punjab', 'Uttar Pradesh', '-1',
#        'Odisha', 'Maharashtra', 'Uttarakhand', 'Assam', 'Bihar',
#        'Andhra Pradesh', 'Karnataka', 'Telangana', 'Kerala', 'Tamil Nadu',
#        'Gujarat', 'Tripura', 'Manipur', 'Nagaland', 'NCT of Delhi',
#        'Jammu & Kashmir', 'Chhattisgarh', 'Haryana', 'Madhya Pradesh',
#        'Goa'], dtype=object)

# %%
pd.unique(df['region'])
# Out:
# array(['East', 'West', 'North', '-1', 'North East', 'South', 'Central',
#        nan], dtype=object)

# %%
pd.unique(df['course'])
# Out:
# array(['dessert', 'main course', 'starter', 'snack'], dtype=object)

# %%
min_prepTime = df['prep_time'].min()
max_prepTime = df['prep_time'].max()

print("Min Prep time: ", min_prepTime, "; Max Prep time: ", max_prepTime)
# Out:
# Min Prep time:  -1 ; Max Prep time:  500

# %%
min_cookTime = df['cook_time'].min()
max_cookTime = df['cook_time'].max()

print("Min Cook time: ", min_cookTime, "; Max Cook time: ", max_cookTime)
# Out:
# Min Cook time:  -1 ; Max Cook time:  720

# %%
df['prep_time'].describe()
# Out:
# count    255.000000
# mean      31.105882
# std       72.554409
# min       -1.000000
# 25%       10.000000
# 50%       10.000000
# 75%       20.000000
# max      500.000000
# Name: prep_time, dtype: float64

# %%
df['cook_time'].describe()
# Out:
# count    255.000000
# mean      34.529412
# std       48.265650
# min       -1.000000
# 25%       20.000000
# 50%       30.000000
# 75%       40.000000
# max      720.000000
# Name: cook_time, dtype: float64

# %%
df['diet'].value_counts()
# Out:
# diet
# vegetarian        226
# non vegetarian     29
# Name: count, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# West          74
# South         59
# North         49
# East          31
# North East    25
# -1            13
# Central        3
# Name: count, dtype: int64

# %%
df['state'].value_counts()
# Out:
# state
# Gujarat            35
# Punjab             32
# Maharashtra        30
# West Bengal        24
# -1                 24
# Assam              21
# Tamil Nadu         20
# Andhra Pradesh     10
# Uttar Pradesh       9
# Kerala              8
# Odisha              7
# Karnataka           6
# Rajasthan           6
# Telangana           5
# Bihar               3
# Goa                 3
# Manipur             2
# Jammu & Kashmir     2
# Madhya Pradesh      2
# Uttarakhand         1
# Tripura             1
# Nagaland            1
# NCT of Delhi        1
# Chhattisgarh        1
# Haryana             1
# Name: count, dtype: int64

# %%
df['flavor_profile'].value_counts()
# Out:
# flavor_profile
# spicy     133
# sweet      88
# -1         29
# bitter      4
# sour        1
# Name: count, dtype: int64

# %%
df['course'].value_counts()
# Out:
# course
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: count, dtype: int64

# %% [markdown]
# ### 🔹 Observation
# - `-1` is used in different features for unavailable data

# %% [markdown]
# ### 🔹 Basic Metric Summary
# - 2 major `diet` preference; mostly veg
# - cook time is generally higher then prep time; with some exception require lot of time
# - 4 flavour types also there is `-1` i.e NA
# - 4 meal course
# - 5 regions and `-1` for unavailable region

# %% [markdown]
# ## 🔷 Data Preprocessing

# %%
df.columns.tolist()
# Out:
# ['name',
#  'ingredients',
#  'diet',
#  'prep_time',
#  'cook_time',
#  'flavor_profile',
#  'course',
#  'state',
#  'region']

# %% [markdown]
# ### 🔹1. Data Type Conversion

# %%
## Convert ingredient feature
print(type(df['ingredients'].iloc[0]))
# Out:
# <class 'str'>

# %%
df['ingredients'].head(3)
# Out:
# 0                 Maida flour, yogurt, oil, sugar
# 1                         Gram flour, ghee, sugar
# 2    Carrots, milk, sugar, ghee, cashews, raisins
# Name: ingredients, dtype: object

# %%
df['ingredients_list'] = df["ingredients"].apply(lambda x: [i.strip() for i in x.split(',')])

# %%
df['ingredients_list'].head(3)
# Out:
# 0                 [Maida flour, yogurt, oil, sugar]
# 1                         [Gram flour, ghee, sugar]
# 2    [Carrots, milk, sugar, ghee, cashews, raisins]
# Name: ingredients_list, dtype: object

# %%
df["diet"].unique()
# Out:
# array(['vegetarian', 'non vegetarian'], dtype=object)

# %%
## Converting data type of diet
df['diet'] = df['diet'].astype('category')

# %%
df['diet'].dtype
# Out:
# CategoricalDtype(categories=['non vegetarian', 'vegetarian'], ordered=False, categories_dtype=object)

# %%
df['flavor_profile'].unique()
# Out:
# array(['sweet', 'spicy', 'bitter', '-1', 'sour'], dtype=object)

# %%
## replacing -1 to unknown
df['flavor_profile'] = df['flavor_profile'].replace('-1', 'unknown')

# %%
## changing type to category
df['flavor_profile'] = df['flavor_profile'].astype('category')

# %%
df['flavor_profile'].dtype
# Out:
# CategoricalDtype(categories=['bitter', 'sour', 'spicy', 'sweet', 'unknown'], ordered=False, categories_dtype=object)

# %%
df['course'].unique()
# Out:
# array(['dessert', 'main course', 'starter', 'snack'], dtype=object)

# %%
## changing type to category
df['course'] = df['course'].astype('category')

# %%
df['state'].unique()
# Out:
# array(['West Bengal', 'Rajasthan', 'Punjab', 'Uttar Pradesh', '-1',
#        'Odisha', 'Maharashtra', 'Uttarakhand', 'Assam', 'Bihar',
#        'Andhra Pradesh', 'Karnataka', 'Telangana', 'Kerala', 'Tamil Nadu',
#        'Gujarat', 'Tripura', 'Manipur', 'Nagaland', 'NCT of Delhi',
#        'Jammu & Kashmir', 'Chhattisgarh', 'Haryana', 'Madhya Pradesh',
#        'Goa'], dtype=object)

# %%
## replacing -1 to unknown
df['state'] = df['state'].replace('-1', 'unknown')

# %%
## changing type to category
df['state'] = df['state'].astype('category')

# %%
df['region'].unique()
# Out:
# array(['East', 'West', 'North', '-1', 'North East', 'South', 'Central',
#        nan], dtype=object)

# %%
df['region'] = df['region'].replace('-1','unknown')

# %%
df['region']=df['region'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              255 non-null    object
#  1   ingredients       255 non-null    object
#  2   diet              255 non-null    category
#  3   prep_time         255 non-null    int64
#  4   cook_time         255 non-null    int64
#  5   flavor_profile    255 non-null    category
#  6   course            255 non-null    category
#  7   state             255 non-null    category
#  8   region            254 non-null    category
#  9   ingredients_list  255 non-null    object
# dtypes: category(5), int64(2), object(3)
# memory usage: 12.9+ KB

# %% [markdown]
# ### 🔹 2. Null Handling

# %%
df['region'].value_counts()
# Out:
# region
# West          74
# South         59
# North         49
# East          31
# North East    25
# unknown       13
# Central        3
# Name: count, dtype: int64

# %%
df['region'].isnull().sum()
# Out:
# 1

# %%
df['region'] = df['region'].fillna('unknown')

# %%
df['region'].isnull().sum()
# Out:
# 0

# %%
df['region'].value_counts()
# Out:
# region
# West          74
# South         59
# North         49
# East          31
# North East    25
# unknown       14
# Central        3
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              255 non-null    object
#  1   ingredients       255 non-null    object
#  2   diet              255 non-null    category
#  3   prep_time         255 non-null    int64
#  4   cook_time         255 non-null    int64
#  5   flavor_profile    255 non-null    category
#  6   course            255 non-null    category
#  7   state             255 non-null    category
#  8   region            255 non-null    category
#  9   ingredients_list  255 non-null    object
# dtypes: category(5), int64(2), object(3)
# memory usage: 12.9+ KB

# %% [markdown]
# ### 🔹 3. Feature Engineering
# #### 🔹Derived Column
# - `num_ingredients` from `ingredients` --> Number of ingredients
# - `total_time` from `prep_time` & `cook_time` --> total time for a meal
# - `time_category` from `total_time` --> categorizing bazed on time required

# %%
# creating new col
df['num_ingredients'] = df['ingredients_list'].apply(len)

# %%
#verifying new column
df[['ingredients','num_ingredients']].head()
# Out:
#                                          ingredients  num_ingredients
# 0                    Maida flour, yogurt, oil, sugar                4
# 1                            Gram flour, ghee, sugar                3
# 2       Carrots, milk, sugar, ghee, cashews, raisins                6
# 3  Flour, ghee, kewra, milk, clarified butter, su...               10
# 4  Milk powder, plain flour, baking powder, ghee,...                8

# %%
# check its info
df['num_ingredients'].describe()
# Out:
# count    255.000000
# mean       4.454902
# std        1.205681
# min        2.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max       10.000000
# Name: num_ingredients, dtype: float64

# %% [markdown]
# #### 🔹 Observation
# - on an average a dish takes 4-5 ingredients
# - simplest ones use 2 vs complex ones require 10
# - most of dishes(75%) use <=5 ingredients

# %%
df['total_time'] = df['prep_time']+df['cook_time']

# %%
df[['prep_time','cook_time','total_time']].head()
# Out:
#    prep_time  cook_time  total_time
# 0         45         25          70
# 1         80         30         110
# 2         15         60          75
# 3         15         30          45
# 4         15         40          55

# %%
df['total_time'].value_counts()
# Out:
# total_time
#  50     35
#  30     30
# -2      28
#  60     23
#  40     19
#  45     18
#  70     13
#  35     11
#  55      8
#  25      7
#  20      6
#  90      5
#  65      5
#  100     5
#  75      4
#  80      3
#  10      3
#  450     3
#  150     3
#  85      2
#  270     2
#  59      2
#  240     2
#  105     2
#  15      1
#  140     1
#  535     1
#  180     1
#  36      1
#  175     1
#  300     1
#  620     1
#  17      1
#  165     1
#  285     1
#  730     1
#  110     1
#  510     1
#  130     1
#  52      1
# Name: count, dtype: int64

# %%
df[(df['prep_time'] <= 0) | (df['cook_time'] <=0)]
# Out:
#                name                                        ingredients  \
# 19      Sohan papdi            Gram flour, ghee, sugar, milk, cardamom
# 21    Chhena kheeri                                Chhena, sugar, milk
# 65      Pork Bharta   Boiled pork, onions, chillies, ginger and garlic
# 132  Kaara kozhambu  Sesame oil, drumstick, tamarind paste, sambar ...
# 134  Keerai masiyal  Urad dal, curry leaves, sugar, mustard seeds, ...
# 148      Paravannam                           Raw rice,  jaggery, milk
# 152         Poriyal       Chana dal, urad dal, beans, coconut, mustard
# 167     Kolim Jawla  Baingan, fish, coconut oil, fresh coconut, ginger
# 172      Bombil fry  Bombay duck, malvani masala, rice flour, bomba...
# 185        Ghooghra            Dry fruits, semolina, all purpose flour
# 187        Halvasan  Whole wheat rava, chia seed, lemon, edible gum...
# 213      Mag Dhokli      Moong beans, jaggery, red chillies, oil, salt
# 216      Farsi Puri  Semolina, clarified butter, oil, white flour, ...
# 220      Cheera Doi                                  Rice, mango, curd
# 223     Kumol Sawul                       Rice, eggs, carrot, beetroot
# 227  Bengena Pitika     Brinjal, onions, salt, sesame seeds, coriander
# 229      Black rice  Forbidden black rice, chicken, olive oil, sliv...
# 230      Bora Sawul  Biryani masala, mixed vegetables, yellow moong...
# 234      Hando Guri                                   Jaggery, raisins
# 237        Kabiraji            Fish fillet, besan, lemon, mint, ginger
# 238         Khorisa  Fermented bamboo shoot, potato, ginger, green,...
# 239  Koldil Chicken  Banana flower, chicken, green chili, mustard o...
# 240       Konir Dom  Aloo, tomatoes, mustard oil, bay leaf, cinnamo...
# 241     Koldil Duck  Rice flour, mutton, banana, gram flour, olive ...
# 242      Masor Koni  Fish roe, pumpkin flowers, mustard oil, turmer...
# 244         Pakhala        Curd, cooked rice, curry leaves, dry chilli
# 246          Payokh  Basmati rice, rose water, sugar, clarified but...
# 248        Red Rice  Red pepper, red onion, butter, watercress, oli...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 19       vegetarian         -1         60          sweet      dessert
# 21       vegetarian         -1         60          sweet      dessert
# 65   non vegetarian         -1         -1          spicy  main course
# 132      vegetarian         -1         -1          spicy  main course
# 134      vegetarian         -1         -1          spicy  main course
# 148      vegetarian         -1         -1          spicy  main course
# 152      vegetarian         -1         -1          spicy  main course
# 167  non vegetarian         -1         -1          spicy  main course
# 172  non vegetarian         -1         -1          spicy  main course
# 185      vegetarian         -1         -1          spicy        snack
# 187      vegetarian         -1         -1          sweet      dessert
# 213      vegetarian         -1         -1          spicy        snack
# 216      vegetarian         -1         -1        unknown        snack
# 220      vegetarian         -1         -1          sweet      dessert
# 223  non vegetarian         -1         -1          spicy  main course
# 227      vegetarian         -1         -1        unknown  main course
# 229  non vegetarian         -1         -1        unknown  main course
# 230      vegetarian         -1         -1          spicy  main course
# 234      vegetarian         -1         -1          sweet      dessert
# 237  non vegetarian         -1         -1          spicy  main course
# 238      vegetarian         -1         -1          spicy  main course
# 239  non vegetarian         -1         -1          spicy  main course
# 240  non vegetarian         -1         -1          spicy  main course
# 241  non vegetarian         -1         -1          spicy  main course
# 242  non vegetarian         -1         -1          spicy  main course
# 244      vegetarian         -1         -1        unknown  main course
# 246      vegetarian         -1         -1          sweet      dessert
# 248      vegetarian         -1         -1        unknown  main course
# 252      vegetarian         -1         -1          sweet      dessert
# 254      vegetarian         -1         -1          sweet      dessert
#
#                state      region  \
# 19       Maharashtra        West
# 21            Odisha        East
# 65           Tripura  North East
# 132       Tamil Nadu       South
# 134       Tamil Nadu       South
# 148           Kerala       South
# 152       Tamil Nadu       South
# 167      Maharashtra        West
# 172      Maharashtra        West
# 185          Gujarat        West
# 187          Gujarat        West
# 213          Gujarat        West
# 216          Gujarat        West
# 220      West Bengal        East
# 223            Assam  North East
# 227            Assam  North East
# 229          Manipur  North East
# 230            Assam  North East
# 234            Assam  North East
# 237      West Bengal        East
# 238            Assam  North East
# 239            Assam  North East
# 240            Assam  North East
# 241            Assam  North East
# 242            Assam  North East
# 244           Odisha        East
# 246            Assam  North East
# 248          unknown     unknown
# 252  Jammu & Kashmir       North
# 254              Goa        West
#
#                                       ingredients_list  num_ingredients  \
# 19           [Gram flour, ghee, sugar, milk, cardamom]                5
# 21                               [Chhena, sugar, milk]                3
# 65   [Boiled pork, onions, chillies, ginger and gar...                4
# 132  [Sesame oil, drumstick, tamarind paste, sambar...                5
# 134  [Urad dal, curry leaves, sugar, mustard seeds,...                5
# 148                          [Raw rice, jaggery, milk]                3
# 152     [Chana dal, urad dal, beans, coconut, mustard]                5
# 167  [Baingan, fish, coconut oil, fresh coconut, gi...                5
# 172  [Bombay duck, malvani masala, rice flour, bomb...                5
# 185          [Dry fruits, semolina, all purpose flour]                3
# 187  [Whole wheat rava, chia seed, lemon, edible gu...                5
# 213    [Moong beans, jaggery, red chillies, oil, salt]                5
# 216  [Semolina, clarified butter, oil, white flour,...                5
# 220                                [Rice, mango, curd]                3
# 223                     [Rice, eggs, carrot, beetroot]                4
# 227   [Brinjal, onions, salt, sesame seeds, coriander]                5
# 229  [Forbidden black rice, chicken, olive oil, sli...                5
# 230  [Biryani masala, mixed vegetables, yellow moon...                5
# 234                                 [Jaggery, raisins]                2
# 237          [Fish fillet, besan, lemon, mint, ginger]                5
# 238  [Fermented bamboo shoot, potato, ginger, green...                5
# 239  [Banana flower, chicken, green chili, mustard ...                5
# 240  [Aloo, tomatoes, mustard oil, bay leaf, cinnam...                5
# 241  [Rice flour, mutton, banana, gram flour, olive...                6
# 242  [Fish roe, pumpkin flowers, mustard oil, turme...                5
# 244      [Curd, cooked rice, curry leaves, dry chilli]                4
# 246  [Basmati rice, rose water, sugar, clarified bu...                5
# 248  [Red pepper, red onion, butter, watercress, ol...                5
# 252  [Cottage cheese, dry dates, dried rose petals,...                5
# 254  [Brown rice, fennel seeds, grated coconut, bla...                5
#
#      total_time
# 19           59
# 21           59
# 65           -2
# 132          -2
# 134          -2
# 148          -2
# 152          -2
# 167          -2
# 172          -2
# 185          -2
# 187          -2
# 213          -2
# 216          -2
# 220          -2
# 223          -2
# 227          -2
# 229          -2
# 230          -2
# 234          -2
# 237          -2
# 238          -2
# 239          -2
# 240          -2
# 241          -2
# 242          -2
# 244          -2
# 246          -2
# 248          -2
# 252          -2
# 254          -2

# %% [markdown]
# #### ‼️ dealing with prep_time/cook_time == -1

# %%
# Checking skewness
sns.histplot(x = df['prep_time'])
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='prep_time', ylabel='Count'>

# %%
# checking skewness
sns.histplot(x = df['cook_time'])
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='cook_time', ylabel='Count'>

# %%
## Other way to check skewness
print(df['cook_time'].skew())
print(df['prep_time'].skew())
# Out:
# 11.433429571676463
# 4.636300925063016

# %% [markdown]
# ####  Highly right(+ve) skewed
# - use median to replace -1 values in skewed case(more robust than mean)

# %%
# Find median foor cook and prep time
cook_time_median = int(np.round(df['cook_time'].median()))
prep_time_median = int(np.round(df['prep_time'].median()))

print(cook_time_median , prep_time_median)
# Out:
# 30 10

# %%
# replacing -1 with respective median time
df['cook_time'] = df['cook_time'].replace(-1,cook_time_median)
df['prep_time'] = df['prep_time'].replace(-1,prep_time_median)

# %%
# verify again prep and cook time columns
df[(df['prep_time'] <= 0) | (df['cook_time'] <=0)]
# Out:
# Empty DataFrame
# Columns: [name, ingredients, diet, prep_time, cook_time, flavor_profile, course, state, region, ingredients_list, num_ingredients, total_time]
# Index: []

# %%
df['total_time'] = df['prep_time']+df['cook_time']

# %%
total_time = df['total_time']
sns.histplot(x = total_time)
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_time', ylabel='Count'>

# %% [markdown]
# #### ‼️ How to set categories for time spent?

# %%
# 
plt.figure(figsize=(16, 3)) # w=16,h=4
sns.boxplot(x=total_time)

# Set x-ticks at regular intervals
plt.xticks(np.arange(0, total_time.max() + 1, 20))  # every 20 units, adjust as needed

plt.grid(True)
plt.show()

# %% [markdown]
# #### ℹ️ Based on above curve we have finalized following bins to categories total time
#
#
# <div style="text-align: center;">
#   <img src="https://raw.githubusercontent.com/hardikdhamija96/IndianFoodPreference/refs/heads/main/TimeCategory.png" width="400"/>
# </div>

# %%
## creating new column
bins = [0,40,60,90,total_time.max()+1] # +1 to add last element
labels = ['Quick','Moderate','Long','Very Long']

df['time_category'] = pd.cut(total_time, bins=bins, labels=labels,right=False) 
#right=false ---> quick = [0,39]

# %%
df['time_category'].value_counts()
# Out:
# time_category
# Moderate     109
# Quick         60
# Long          52
# Very Long     34
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              255 non-null    object
#  1   ingredients       255 non-null    object
#  2   diet              255 non-null    category
#  3   prep_time         255 non-null    int64
#  4   cook_time         255 non-null    int64
#  5   flavor_profile    255 non-null    category
#  6   course            255 non-null    category
#  7   state             255 non-null    category
#  8   region            255 non-null    category
#  9   ingredients_list  255 non-null    object
#  10  num_ingredients   255 non-null    int64
#  11  total_time        255 non-null    int64
#  12  time_category     255 non-null    category
# dtypes: category(6), int64(4), object(3)
# memory usage: 17.4+ KB
